# %%
print("hello")
print("it's a pleasure to meet you user")
# Out:
# hello
# it's a pleasure to meet you user

# %%
print("yo this system ain't working")
print("                            ")
print("what am i gonna do ")
# Out:
# yo this system ain't working
#
# what am i gonna do
